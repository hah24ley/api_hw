# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)


#cities
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
query_url = "http://api.openweathermap.org/data/2.5/weather?q="

city = []
temp = []
clouds = []
humidity = []
wind_speed = []
country = []
date = []
lat = []
Ing = []


record = 1

print("Beginning Data Retrieval")
print("---------------------------")


for city in cities: 
    url = query_url + city + "&APPID=" + api_key + "&units=Imperial"
    
    try:
        response = requests.get(url).json()
        print(city)
        print(response["main"])
        print(response["wind"]["speed"])
    except:
        print("City not found. Skipping..")
        pass
    

    #city.append(response["name"])
#temp.append(response ["main"]["temp"])
#cloud.append(response ["clouds"]["all"])
#wind_speed.append(response["wind"]["speed"])
#country.append(response ["sys"]["country"])
#date.append(response["dt"])
#lat.append(response ["coord"]["lat"])
#lng.append(response["coord"]["lon"])
#city.append(response["name"])
    
# Create settings dictionary with information we're interested in
#settings = {"units": "metric", "appid": api_key}

# Get current weather
#current_weather_paris = owm.get_current("Paris", **settings)
#print(f"Current weather object for Paris: {current_weather_paris}.")


#summary = ["name", "main.temp"]

#data = current_weather_paris(*summary)
#print(f"The current weather summary for Paris is: {data}.")
# Out:
# Beginning Data Retrieval
# ---------------------------
# castro
# {'temp': 46.4, 'pressure': 1010, 'humidity': 75, 'temp_min': 46.4, 'temp_max': 46.4}
# 9.17
# evensk
# {'temp': 50.53, 'pressure': 1010.23, 'humidity': 98, 'temp_min': 50.53, 'temp_max': 50.53, 'sea_level': 1010.23, 'grnd_level': 991.51}
# 3.56
# tsihombe
# City not found. Skipping..
# mataura
# {'temp': 46, 'pressure': 1008, 'humidity': 97, 'temp_min': 46, 'temp_max': 46}
# 5.99
# birjand
# {'temp': 82.4, 'pressure': 1013, 'humidity': 11, 'temp_min': 82.4, 'temp_max': 82.4}
# 4.7
# huesca
# {'temp': 80.01, 'pressure': 1015, 'humidity': 50, 'temp_min': 78.01, 'temp_max': 82.99}
# 9.17
# victoria
# {'temp': 80.74, 'pressure': 1008, 'humidity': 88, 'temp_min': 80.01, 'temp_max': 82.4}
# 6.55
# viligili
# City not found. Skipping..
# kholodnyy
# {'temp': 38.47, 'pressure': 1011.74, 'humidity': 87, 'temp_min': 38.47, 'temp_max': 38.47, 'sea_level': 1011.74, 'grnd_level': 892.34}
# 5.37
# oranjestad
# {'temp': 87.8, 'pressure': 1011, 'humidity': 70, 'temp_min': 87.8, 'temp_max': 87.8}
# 23.04
# pauini
# {'temp': 89.23, 'pressure': 1008.88, 'humidity': 49, 'temp_min': 89.23, 'temp_max': 89.23, 'sea_level': 1008.88, 'grnd_level': 993.16}
# 1.3
# busayra
# {'temp': 75.55, 'pressure': 1012.85, 'humidity': 65, 'temp_min': 75.55, 'temp_max': 75.55, 'sea_level': 1012.85, 'grnd_level': 1007.76}
# 0.67
# puerto penasco
# {'temp': 94.05, 'pressure': 1009, 'humidity': 22, 'temp_min': 89.01, 'temp_max': 98.6}
# 11.41
# butaritari
# {'temp': 84.91, 'pressure': 1009.59, 'humidity': 66, 'temp_min': 84.91, 'temp_max': 84.91, 'sea_level': 1009.59, 'grnd_level': 1009.64}
# 7.63
# punta arenas
# {'temp': 37.27, 'pressure': 981, 'humidity': 86, 'temp_min': 37, 'temp_max': 37.4}
# 9.17
# severo-kurilsk
# {'temp': 47.29, 'pressure': 1022.85, 'humidity': 99, 'temp_min': 47.29, 'temp_max': 47.29, 'sea_level': 1022.85, 'grnd_level': 1022.76}
# 2.93
# albany
# {'temp': 89.46, 'pressure': 1009, 'humidity': 52, 'temp_min': 84, 'temp_max': 93.99}
# 8.05
# chokurdakh
# {'temp': 37.93, 'pressure': 1019.41, 'humidity': 82, 'temp_min': 37.93, 'temp_max': 37.93, 'sea_level': 1019.41, 'grnd_level': 1017.96}
# 6.24
# east london
# {'temp': 50.35, 'pressure': 1018.5, 'humidity': 54, 'temp_min': 50.35, 'temp_max': 50.35, 'sea_level': 1018.5, 'grnd_level': 982.26}
# 23.15
# varzea da palma
# {'temp': 67.99, 'pressure': 1021.05, 'humidity': 48, 'temp_min': 67.99, 'temp_max': 67.99, 'sea_level': 1021.05, 'grnd_level': 952.79}
# 7.74
# arraial do cabo
# {'temp': 68.88, 'pressure': 1025, 'humidity': 64, 'temp_min': 68, 'temp_max': 69.8}
# 14.99
# cootamundra
# {'temp': 39, 'pressure': 1022, 'humidity': 96, 'temp_min': 39, 'temp_max': 39}
# 1.99
# temaraia
# City not found. Skipping..
# coihaique
# {'temp': 35.69, 'pressure': 1001, 'humidity': 98, 'temp_min': 33.8, 'temp_max': 39.2}
# 8.05
# bethel
# {'temp': 55.4, 'pressure': 1020, 'humidity': 87, 'temp_min': 55.4, 'temp_max': 55.4}
# 6.93
# port hardy
# {'temp': 57.2, 'pressure': 1021, 'humidity': 87, 'temp_min': 57.2, 'temp_max': 57.2}
# 4.7
# caronport
# {'temp': 67.8, 'pressure': 1006, 'humidity': 40, 'temp_min': 64.99, 'temp_max': 71.6}
# 29.97
# new norfolk
# {'temp': 39.96, 'pressure': 1015, 'humidity': 81, 'temp_min': 37, 'temp_max': 42.8}
# 13.87
# kapaa
# {'temp': 82.4, 'pressure': 1018, 'humidity': 74, 'temp_min': 79, 'temp_max': 84.2}
# 17.22
# vaitupu
# City not found. Skipping..
# vardo
# {'temp': 94.75, 'pressure': 1014, 'humidity': 56, 'temp_min': 91.99, 'temp_max': 98.01}
# 10.29
# kingsville
# {'temp': 93.51, 'pressure': 1014, 'humidity': 50, 'temp_min': 88, 'temp_max': 98.6}
# 18.34
# hobart
# {'temp': 39.69, 'pressure': 1015, 'humidity': 81, 'temp_min': 37, 'temp_max': 42.8}
# 13.87
# thompson
# {'temp': 68, 'pressure': 1003, 'humidity': 64, 'temp_min': 68, 'temp_max': 68}
# 13.87
# santa isabel do rio negro
# {'temp': 77.35, 'pressure': 1010.82, 'humidity': 83, 'temp_min': 77.35, 'temp_max': 77.35, 'sea_level': 1010.82, 'grnd_level': 1002.16}
# 4.05
# cidreira
# {'temp': 62.95, 'pressure': 1019.73, 'humidity': 77, 'temp_min': 62.95, 'temp_max': 62.95, 'sea_level': 1019.73, 'grnd_level': 1019}
# 7.02
# constantine
# {'temp': 77, 'pressure': 1018, 'humidity': 41, 'temp_min': 77, 'temp_max': 77}
# 4.7
# kruisfontein
# {'temp': 48.91, 'pressure': 1021.84, 'humidity': 70, 'temp_min': 48.91, 'temp_max': 48.91, 'sea_level': 1021.84, 'grnd_level': 989.28}
# 27.69
# bluff
# {'temp': 49.81, 'pressure': 1022.2, 'humidity': 72, 'temp_min': 49.81, 'temp_max': 49.81, 'sea_level': 1022.2, 'grnd_level': 1001.12}
# 8.5
# felipe carrillo puerto
# {'temp': 97.69, 'pressure': 1011.56, 'humidity': 32, 'temp_min': 97.69, 'temp_max': 97.69, 'sea_level': 1011.56, 'grnd_level': 1007.72}
# 7.72
# ortakoy
# {'temp': 68, 'pressure': 1018, 'humidity': 56, 'temp_min': 68, 'temp_max': 68}
# 10.29
# vila franca do campo
# {'temp': 71.6, 'pressure': 1023, 'humidity': 94, 'temp_min': 71.6, 'temp_max': 71.6}
# 11.41
# tuktoyaktuk
# {'temp': 51.8, 'pressure': 1011, 'humidity': 93, 'temp_min': 51.8, 'temp_max': 51.8}
# 11.41
# vaini
# {'temp': 77.35, 'pressure': 1003.26, 'humidity': 90, 'temp_min': 77.35, 'temp_max': 77.35, 'sea_level': 1003.26, 'grnd_level': 995.84}
# 2.66
# pokrovsk
# {'temp': 46.03, 'pressure': 1016.38, 'humidity': 59, 'temp_min': 46.03, 'temp_max': 46.03, 'sea_level': 1016.38, 'grnd_level': 996.39}
# 4.38
# jamestown
# {'temp': 48.91, 'pressure': 1016.07, 'humidity': 46, 'temp_min': 48.91, 'temp_max': 48.91, 'sea_level': 1016.07, 'grnd_level': 979.03}
# 11.74
# longyearbyen
# {'temp': 46.4, 'pressure': 1014, 'humidity': 75, 'temp_min': 46.4, 'temp_max': 46.4}
# 8.05
# chapais
# {'temp': 77, 'pressure': 1000, 'humidity': 61, 'temp_min': 77, 'temp_max': 77}
# 16.11
# mahebourg
# {'temp': 70.16, 'pressure': 1022, 'humidity': 83, 'temp_min': 69.01, 'temp_max': 71.6}
# 17.22
# labuhan
# {'temp': 71.77, 'pressure': 1008.42, 'humidity': 91, 'temp_min': 71.77, 'temp_max': 71.77, 'sea_level': 1008.42, 'grnd_level': 995.49}
# 1.16
# rikitea
# {'temp': 67.09, 'pressure': 1015.43, 'humidity': 64, 'temp_min': 67.09, 'temp_max': 67.09, 'sea_level': 1015.43, 'grnd_level': 1015.11}
# 15.08
# mustasaari
# {'temp': 56.93, 'pressure': 1013, 'humidity': 77, 'temp_min': 55, 'temp_max': 59}
# 3.36
# broome
# {'temp': 63.91, 'pressure': 1009, 'humidity': 93, 'temp_min': 62.01, 'temp_max': 66}
# 10.29
# atuona
# {'temp': 80.05, 'pressure': 1011.64, 'humidity': 71, 'temp_min': 80.05, 'temp_max': 80.05, 'sea_level': 1011.64, 'grnd_level': 1011.8}
# 10.6
# camacha
# {'temp': 71.6, 'pressure': 1020, 'humidity': 83, 'temp_min': 71.6, 'temp_max': 71.6}
# 17.22
# dikson
# {'temp': 37.75, 'pressure': 1016.94, 'humidity': 86, 'temp_min': 37.75, 'temp_max': 37.75, 'sea_level': 1016.94, 'grnd_level': 1016.77}
# 22.48
# sao jose da coroa grande
# {'temp': 71.77, 'pressure': 1017.95, 'humidity': 92, 'temp_min': 71.77, 'temp_max': 71.77, 'sea_level': 1017.95, 'grnd_level': 1006.64}
# 7.96
# palabuhanratu
# City not found. Skipping..
# meulaboh
# {'temp': 76.45, 'pressure': 1008.17, 'humidity': 94, 'temp_min': 76.45, 'temp_max': 76.45, 'sea_level': 1008.17, 'grnd_level': 1007.99}
# 6.89
# port-gentil
# {'temp': 77, 'pressure': 1015, 'humidity': 94, 'temp_min': 77, 'temp_max': 77}
# 8.05
# bredasdorp
# {'temp': 46.4, 'pressure': 1025, 'humidity': 87, 'temp_min': 46.4, 'temp_max': 46.4}
# 9.17
# port alfred
# {'temp': 54, 'pressure': 1017, 'humidity': 76, 'temp_min': 54, 'temp_max': 54}
# 11.01
# busselton
# {'temp': 42.35, 'pressure': 1004, 'humidity': 98, 'temp_min': 42.01, 'temp_max': 43}
# 28.41
# cefalu
# {'temp': 72.99, 'pressure': 1013, 'humidity': 75, 'temp_min': 68, 'temp_max': 78.01}
# 1.01
# sur
# {'temp': 76.63, 'pressure': 1000.19, 'humidity': 84, 'temp_min': 76.63, 'temp_max': 76.63, 'sea_level': 1000.19, 'grnd_level': 982.2}
# 11.41
# illoqqortoormiut
# City not found. Skipping..
# taolanaro
# City not found. Skipping..
# cape town
# {'temp': 50.05, 'pressure': 1028, 'humidity': 87, 'temp_min': 48.2, 'temp_max': 51.01}
# 6.93
# salym
# {'temp': 60.79, 'pressure': 1011.77, 'humidity': 82, 'temp_min': 60.79, 'temp_max': 60.79, 'sea_level': 1011.77, 'grnd_level': 1003.12}
# 1.43
# airai
# {'temp': 66.55, 'pressure': 1012.37, 'humidity': 87, 'temp_min': 66.55, 'temp_max': 66.55, 'sea_level': 1012.37, 'grnd_level': 976.8}
# 5.32
# bozeman
# {'temp': 70.68, 'pressure': 1014, 'humidity': 27, 'temp_min': 63, 'temp_max': 75.99}
# 5.82
# peniche
# {'temp': 63.82, 'pressure': 1014, 'humidity': 72, 'temp_min': 62.01, 'temp_max': 66.2}
# 20.8
# bathsheba
# {'temp': 86, 'pressure': 1014, 'humidity': 66, 'temp_min': 86, 'temp_max': 86}
# 16.11
# klaksvik
# {'temp': 50, 'pressure': 1000, 'humidity': 100, 'temp_min': 50, 'temp_max': 50}
# 12.75
# saskylakh
# {'temp': 58.81, 'pressure': 1020.69, 'humidity': 46, 'temp_min': 58.81, 'temp_max': 58.81, 'sea_level': 1020.69, 'grnd_level': 1010.95}
# 12.35
# novikovo
# {'temp': 57.73, 'pressure': 1015.45, 'humidity': 91, 'temp_min': 57.73, 'temp_max': 57.73, 'sea_level': 1015.45, 'grnd_level': 992.29}
# 7.92
# siniscola
# {'temp': 64.93, 'pressure': 1016.17, 'humidity': 72, 'temp_min': 64.93, 'temp_max': 64.93, 'sea_level': 1016.17, 'grnd_level': 966}
# 1.03
# ushuaia
# {'temp': 38.19, 'pressure': 978, 'humidity': 60, 'temp_min': 37.4, 'temp_max': 39.2}
# 13.87
# arlit
# {'temp': 96.97, 'pressure': 1007.28, 'humidity': 18, 'temp_min': 96.97, 'temp_max': 96.97, 'sea_level': 1007.28, 'grnd_level': 960.2}
# 14.81
# mount gambier
# {'temp': 48.2, 'pressure': 1014, 'humidity': 70, 'temp_min': 48.2, 'temp_max': 48.2}
# 14.99
# barrow
# {'temp': 50.89, 'pressure': 1012.04, 'humidity': 50, 'temp_min': 50.89, 'temp_max': 50.89, 'sea_level': 1012.04, 'grnd_level': 1000.52}
# 14.23
# ostrovnoy
# {'temp': 40.27, 'pressure': 1015.62, 'humidity': 98, 'temp_min': 40.27, 'temp_max': 40.27, 'sea_level': 1015.62, 'grnd_level': 998.84}
# 6.38
# mar del plata
# {'temp': 43.69, 'pressure': 996.55, 'humidity': 43, 'temp_min': 43.69, 'temp_max': 43.69, 'sea_level': 996.55, 'grnd_level': 962.12}
# 21.36
# bengkulu
# City not found. Skipping..
# hobyo
# {'temp': 77.71, 'pressure': 1011.18, 'humidity': 61, 'temp_min': 77.71, 'temp_max': 77.71, 'sea_level': 1011.18, 'grnd_level': 1003.44}
# 25.12
# nikolskoye
# {'temp': 60.94, 'pressure': 1007, 'humidity': 93, 'temp_min': 60.8, 'temp_max': 61}
# 8.95
# vallenar
# {'temp': 75.91, 'pressure': 1013.59, 'humidity': 24, 'temp_min': 75.91, 'temp_max': 75.91, 'sea_level': 1013.59, 'grnd_level': 951.52}
# 5.57
# la uribe
# City not found. Skipping..
# hadejia
# {'temp': 84.55, 'pressure': 1012.56, 'humidity': 52, 'temp_min': 84.55, 'temp_max': 84.55, 'sea_level': 1012.56, 'grnd_level': 971.38}
# 8.05
# chagda
# City not found. Skipping..
# sertania
# {'temp': 70.15, 'pressure': 1017.34, 'humidity': 80, 'temp_min': 70.15, 'temp_max': 70.15, 'sea_level': 1017.34, 'grnd_level': 949.43}
# 16.28
# cap malheureux
# {'temp': 70.47, 'pressure': 1022, 'humidity': 83, 'temp_min': 69.01, 'temp_max': 71.6}
# 17.22
# beyneu
# {'temp': 91.93, 'pressure': 1007.63, 'humidity': 29, 'temp_min': 91.93, 'temp_max': 91.93, 'sea_level': 1007.63, 'grnd_level': 1007.78}
# 17.94
# hilo
# {'temp': 80.1, 'pressure': 1017, 'humidity': 69, 'temp_min': 77, 'temp_max': 82.99}
# 9.17
# te anau
# {'temp': 42.79, 'pressure': 1004.13, 'humidity': 88, 'temp_min': 42.79, 'temp_max': 42.79, 'sea_level': 1004.13, 'grnd_level': 951.14}
# 6.58
# alice springs
# {'temp': 44.6, 'pressure': 1019, 'humidity': 39, 'temp_min': 44.6, 'temp_max': 44.6}
# 2.24
# cherlak
# {'temp': 61.69, 'pressure': 1009.82, 'humidity': 93, 'temp_min': 61.69, 'temp_max': 61.69, 'sea_level': 1009.82, 'grnd_level': 997.72}
# 7.78
# amderma
# City not found. Skipping..
# gannan
# {'temp': 67.81, 'pressure': 1001.27, 'humidity': 91, 'temp_min': 67.81, 'temp_max': 67.81, 'sea_level': 1001.27, 'grnd_level': 963.11}
# 6.51
# zhezkazgan
# {'temp': 75.73, 'pressure': 1010.3, 'humidity': 35, 'temp_min': 75.73, 'temp_max': 75.73, 'sea_level': 1010.3, 'grnd_level': 964.96}
# 7.29
# severo-yeniseyskiy
# {'temp': 48.19, 'pressure': 1014.45, 'humidity': 71, 'temp_min': 48.19, 'temp_max': 48.19, 'sea_level': 1014.45, 'grnd_level': 966.26}
# 5.08
# at-bashi
# {'temp': 53.77, 'pressure': 1014.12, 'humidity': 43, 'temp_min': 53.77, 'temp_max': 53.77, 'sea_level': 1014.12, 'grnd_level': 762.87}
# 4.07
# georgetown
# {'temp': 81.57, 'pressure': 1012, 'humidity': 88, 'temp_min': 80.6, 'temp_max': 82.4}
# 11.41
# algiers
# {'temp': 91.13, 'pressure': 1018, 'humidity': 66, 'temp_min': 86, 'temp_max': 95}
# 4.88
# marawi
# {'temp': 75.99, 'pressure': 1009, 'humidity': 89, 'temp_min': 75.99, 'temp_max': 75.99}
# 4
# qaanaaq
# {'temp': 39.19, 'pressure': 1006.77, 'humidity': 90, 'temp_min': 39.19, 'temp_max': 39.19, 'sea_level': 1006.77, 'grnd_level': 969.64}
# 3.91
# tumannyy
# City not found. Skipping..
# port lincoln
# {'temp': 60.25, 'pressure': 1008.86, 'humidity': 57, 'temp_min': 60.25, 'temp_max': 60.25, 'sea_level': 1008.86, 'grnd_level': 1008.79}
# 30.29
# saleaula
# City not found. Skipping..
# chuy
# {'temp': 57.01, 'pressure': 1017.48, 'humidity': 87, 'temp_min': 57.01, 'temp_max': 57.01, 'sea_level': 1017.48, 'grnd_level': 1016.72}
# 5.46
# sioux lookout
# {'temp': 74.52, 'pressure': 1004, 'humidity': 78, 'temp_min': 73.4, 'temp_max': 75.2}
# 6.93
# shillong
# {'temp': 80.6, 'pressure': 1003, 'humidity': 94, 'temp_min': 80.6, 'temp_max': 80.6}
# 4.7
# puerto ayora
# {'temp': 73.71, 'pressure': 1010, 'humidity': 65, 'temp_min': 70, 'temp_max': 77}
# 17.22
# kilindoni
# {'temp': 76.45, 'pressure': 1016.3, 'humidity': 79, 'temp_min': 76.45, 'temp_max': 76.45, 'sea_level': 1016.3, 'grnd_level': 1016.18}
# 10.56
# tasiilaq
# {'temp': 48.2, 'pressure': 1013, 'humidity': 70, 'temp_min': 48.2, 'temp_max': 48.2}
# 9.17
# sorland
# {'temp': 66.2, 'pressure': 1009, 'humidity': 52, 'temp_min': 66.2, 'temp_max': 66.2}
# 6.93
# banff
# {'temp': 52, 'pressure': 1004, 'humidity': 78, 'temp_min': 52, 'temp_max': 52}
# 7
# larsnes
# {'temp': 55.2, 'pressure': 1010, 'humidity': 93, 'temp_min': 50, 'temp_max': 60.8}
# 4.7
# bowen
# {'temp': 48.67, 'pressure': 1019, 'humidity': 100, 'temp_min': 41, 'temp_max': 57}
# 3.85
# itaituba
# {'temp': 87.8, 'pressure': 1011, 'humidity': 62, 'temp_min': 87.8, 'temp_max': 87.8}
# 9.17
# palaikastron
# {'temp': 78.01, 'pressure': 1013, 'humidity': 57, 'temp_min': 78.01, 'temp_max': 78.01}
# 5.99
# quatre cocos
# {'temp': 70.3, 'pressure': 1022, 'humidity': 83, 'temp_min': 69.01, 'temp_max': 71.6}
# 17.22
# cukai
# {'temp': 78.94, 'pressure': 1007, 'humidity': 100, 'temp_min': 77, 'temp_max': 80.6}
# 1.81
# palmer
# {'temp': 54.12, 'pressure': 1014, 'humidity': 43, 'temp_min': 51.01, 'temp_max': 55.99}
# 16.11
# saint-pierre
# {'temp': 67.08, 'pressure': 1013, 'humidity': 49, 'temp_min': 64.4, 'temp_max': 71.6}
# 4.7
# mys shmidta
# City not found. Skipping..
# la paz
# {'temp': 96.06, 'pressure': 1009, 'humidity': 23, 'temp_min': 93.99, 'temp_max': 98.6}
# 17.22
# nemuro
# {'temp': 58.09, 'pressure': 1016.95, 'humidity': 97, 'temp_min': 58.09, 'temp_max': 58.09, 'sea_level': 1016.95, 'grnd_level': 1017.14}
# 12.46
# alofi
# {'temp': 75.2, 'pressure': 1014, 'humidity': 100, 'temp_min': 75.2, 'temp_max': 75.2}
# 8.05
# provideniya
# {'temp': 56.65, 'pressure': 1013.45, 'humidity': 73, 'temp_min': 56.65, 'temp_max': 56.65, 'sea_level': 1013.45, 'grnd_level': 975.52}
# 7.02
# dhidhdhoo
# {'temp': 82.57, 'pressure': 1006.91, 'humidity': 79, 'temp_min': 82.57, 'temp_max': 82.57, 'sea_level': 1006.91, 'grnd_level': 1007}
# 21.77
# comodoro rivadavia
# {'temp': 50, 'pressure': 997, 'humidity': 43, 'temp_min': 50, 'temp_max': 50}
# 23.04
# kayerkan
# {'temp': 59, 'pressure': 1020, 'humidity': 54, 'temp_min': 59, 'temp_max': 59}
# 8.95
# isangel
# {'temp': 71.6, 'pressure': 1013, 'humidity': 73, 'temp_min': 71.6, 'temp_max': 71.6}
# 5.82
# saint-francois
# {'temp': 71.1, 'pressure': 1014, 'humidity': 50, 'temp_min': 68, 'temp_max': 75.2}
# 3.36
# deputatskiy
# {'temp': 36.85, 'pressure': 1021.49, 'humidity': 84, 'temp_min': 36.85, 'temp_max': 36.85, 'sea_level': 1021.49, 'grnd_level': 955.8}
# 5.88
# port elizabeth
# {'temp': 92.97, 'pressure': 1013, 'humidity': 59, 'temp_min': 87.01, 'temp_max': 97}
# 4.7
# cabo san lucas
# {'temp': 86.34, 'pressure': 1013, 'humidity': 49, 'temp_min': 75.99, 'temp_max': 93}
# 8.05
# salalah
# {'temp': 80.6, 'pressure': 1002, 'humidity': 88, 'temp_min': 80.6, 'temp_max': 80.6}
# 3.36
# ban nahin
# {'temp': 74.65, 'pressure': 1004.87, 'humidity': 97, 'temp_min': 74.65, 'temp_max': 74.65, 'sea_level': 1004.87, 'grnd_level': 966.55}
# 1.36
# sao gotardo
# {'temp': 66, 'pressure': 1017, 'humidity': 57, 'temp_min': 66, 'temp_max': 66}
# 1.99
# verkh-usugli
# {'temp': 56.65, 'pressure': 1001.43, 'humidity': 98, 'temp_min': 56.65, 'temp_max': 56.65, 'sea_level': 1001.43, 'grnd_level': 887.43}
# 6.33
# avarua
# {'temp': 75.2, 'pressure': 1015, 'humidity': 88, 'temp_min': 75.2, 'temp_max': 75.2}
# 4.7
# ribeira grande
# {'temp': 75.2, 'pressure': 1022, 'humidity': 83, 'temp_min': 75.2, 'temp_max': 75.2}
# 11.41
# vao
# {'temp': 56.29, 'pressure': 1010.44, 'humidity': 94, 'temp_min': 56.29, 'temp_max': 56.29, 'sea_level': 1010.44, 'grnd_level': 1003.75}
# 3.13
# sumbe
# {'temp': 70.33, 'pressure': 1015.52, 'humidity': 84, 'temp_min': 70.33, 'temp_max': 70.33, 'sea_level': 1015.52, 'grnd_level': 1015.06}
# 5.82
# yellowknife
# {'temp': 68, 'pressure': 1014, 'humidity': 45, 'temp_min': 68, 'temp_max': 68}
# 10.29
# esperance
# {'temp': 48.2, 'pressure': 1005, 'humidity': 93, 'temp_min': 48.2, 'temp_max': 48.2}
# 23.04
# nampa
# {'temp': 75.61, 'pressure': 1016, 'humidity': 19, 'temp_min': 72, 'temp_max': 80.6}
# 8.05
# jining
# {'temp': 74.29, 'pressure': 1002.51, 'humidity': 89, 'temp_min': 74.29, 'temp_max': 74.29, 'sea_level': 1002.51, 'grnd_level': 998.34}
# 5.14
# hithadhoo
# {'temp': 82.93, 'pressure': 1007.28, 'humidity': 78, 'temp_min': 82.93, 'temp_max': 82.93, 'sea_level': 1007.28, 'grnd_level': 1007.08}
# 16.87
# tura
# {'temp': 46.93, 'pressure': 1023.87, 'humidity': 70, 'temp_min': 46.93, 'temp_max': 46.93, 'sea_level': 1023.87, 'grnd_level': 978}
# 3.18
# nova odesa
# {'temp': 67.09, 'pressure': 1018.17, 'humidity': 58, 'temp_min': 67.09, 'temp_max': 67.09, 'sea_level': 1018.17, 'grnd_level': 1009.72}
# 3.22
# cascais
# {'temp': 65.91, 'pressure': 1014, 'humidity': 72, 'temp_min': 63, 'temp_max': 71.6}
# 20.8
# khatanga
# {'temp': 58.27, 'pressure': 1019.14, 'humidity': 57, 'temp_min': 58.27, 'temp_max': 58.27, 'sea_level': 1019.14, 'grnd_level': 1015.99}
# 6.73
# adre
# {'temp': 81.85, 'pressure': 1011.8, 'humidity': 53, 'temp_min': 81.85, 'temp_max': 81.85, 'sea_level': 1011.8, 'grnd_level': 915.49}
# 4.43
# hualmay
# {'temp': 62.05, 'pressure': 1011.28, 'humidity': 83, 'temp_min': 62.05, 'temp_max': 62.05, 'sea_level': 1011.28, 'grnd_level': 1010.16}
# 10.92
# adjumani
# {'temp': 68.53, 'pressure': 1013.55, 'humidity': 86, 'temp_min': 68.53, 'temp_max': 68.53, 'sea_level': 1013.55, 'grnd_level': 931.49}
# 2.64
# toliary
# City not found. Skipping..
# aflu
# City not found. Skipping..
# ucluelet
# {'temp': 66.81, 'pressure': 1021, 'humidity': 72, 'temp_min': 62.6, 'temp_max': 71.01}
# 11.41
# umzimvubu
# City not found. Skipping..
# knysna
# {'temp': 48.2, 'pressure': 1023, 'humidity': 70, 'temp_min': 48.2, 'temp_max': 48.2}
# 16.11
# a coruna
# {'temp': 65.57, 'pressure': 1015, 'humidity': 82, 'temp_min': 63, 'temp_max': 69.8}
# 6.93
# fevralsk
# City not found. Skipping..
# butterworth
# {'temp': 81.21, 'pressure': 1006, 'humidity': 83, 'temp_min': 80.6, 'temp_max': 82}
# 3.36
# nara
# {'temp': 75.27, 'pressure': 1014, 'humidity': 94, 'temp_min': 73.99, 'temp_max': 77}
# 6.93
# narsaq
# {'temp': 62.6, 'pressure': 1011, 'humidity': 55, 'temp_min': 62.6, 'temp_max': 62.6}
# 9.17
# hermanus
# {'temp': 50, 'pressure': 1026, 'humidity': 75, 'temp_min': 50, 'temp_max': 50}
# 3
# korla
# City not found. Skipping..
# angoche
# {'temp': 67.45, 'pressure': 1017.87, 'humidity': 83, 'temp_min': 67.45, 'temp_max': 67.45, 'sea_level': 1017.87, 'grnd_level': 1012.98}
# 3.02
# sao filipe
# {'temp': 75.73, 'pressure': 1015.82, 'humidity': 84, 'temp_min': 75.73, 'temp_max': 75.73, 'sea_level': 1015.82, 'grnd_level': 1015.89}
# 14.29
# eston
# {'temp': 58.08, 'pressure': 1006, 'humidity': 87, 'temp_min': 57.2, 'temp_max': 59}
# 20.8
# kargasok
# {'temp': 63.13, 'pressure': 1010.2, 'humidity': 87, 'temp_min': 63.13, 'temp_max': 63.13, 'sea_level': 1010.2, 'grnd_level': 1002.52}
# 3.29
# zigong
# {'temp': 73.39, 'pressure': 1003.03, 'humidity': 91, 'temp_min': 73.39, 'temp_max': 73.39, 'sea_level': 1003.03, 'grnd_level': 949.49}
# 5.61
# raudeberg
# {'temp': 57.33, 'pressure': 1011, 'humidity': 87, 'temp_min': 55.4, 'temp_max': 60.8}
# 5.82
# balaipungut
# {'temp': 72.13, 'pressure': 1007.57, 'humidity': 87, 'temp_min': 72.13, 'temp_max': 72.13, 'sea_level': 1007.57, 'grnd_level': 1003.04}
# 1.97
# vila velha
# {'temp': 82.78, 'pressure': 1013, 'humidity': 69, 'temp_min': 80.01, 'temp_max': 86}
# 17.22
# kalevala
# {'temp': 53.05, 'pressure': 1012.92, 'humidity': 97, 'temp_min': 53.05, 'temp_max': 53.05, 'sea_level': 1012.92, 'grnd_level': 988.85}
# 4.41
# amahai
# {'temp': 80.01, 'pressure': 1011, 'humidity': 93, 'temp_min': 80.01, 'temp_max': 80.01}
# 7.74
# puerto carreno
# {'temp': 77, 'pressure': 1011, 'humidity': 94, 'temp_min': 77, 'temp_max': 77}
# 3.96
# lorengau
# {'temp': 80.77, 'pressure': 1008.94, 'humidity': 81, 'temp_min': 80.77, 'temp_max': 80.77, 'sea_level': 1008.94, 'grnd_level': 1000.72}
# 9.19
# koutsouras
# {'temp': 78.01, 'pressure': 1013, 'humidity': 57, 'temp_min': 78.01, 'temp_max': 78.01}
# 5.99
# fortuna
# {'temp': 68.97, 'pressure': 1014, 'humidity': 68, 'temp_min': 62.6, 'temp_max': 87.01}
# 18.34
# bud
# {'temp': 54.9, 'pressure': 1011, 'humidity': 87, 'temp_min': 50, 'temp_max': 57.99}
# 8.05
# clyde river
# {'temp': 42.8, 'pressure': 1001, 'humidity': 87, 'temp_min': 42.8, 'temp_max': 42.8}
# 14.99
# jacmel
# {'temp': 93, 'pressure': 1013, 'humidity': 56, 'temp_min': 93, 'temp_max': 93}
# 3
# mao
# {'temp': 89.62, 'pressure': 1015, 'humidity': 59, 'temp_min': 87.01, 'temp_max': 91.4}
# 16.11
# korcula
# {'temp': 77, 'pressure': 1015, 'humidity': 53, 'temp_min': 77, 'temp_max': 77}
# 3.36
# areia branca
# {'temp': 78.8, 'pressure': 1018, 'humidity': 65, 'temp_min': 78.8, 'temp_max': 78.8}
# 13.87
# santos dumont
# {'temp': 60.8, 'pressure': 1028, 'humidity': 63, 'temp_min': 60.8, 'temp_max': 60.8}
# 5.82
# oussouye
# {'temp': 80.6, 'pressure': 1013, 'humidity': 74, 'temp_min': 80.6, 'temp_max': 80.6}
# 11.41
# ashtabula
# {'temp': 89.69, 'pressure': 1013, 'humidity': 70, 'temp_min': 86, 'temp_max': 93.99}
# 10.29
# bambous virieux
# {'temp': 70.21, 'pressure': 1022, 'humidity': 83, 'temp_min': 69.01, 'temp_max': 71.6}
# 17.22
# north branch
# {'temp': 89.83, 'pressure': 1003, 'humidity': 66, 'temp_min': 82.99, 'temp_max': 93}
# 6.93
# auchi
# {'temp': 71.41, 'pressure': 1014.34, 'humidity': 97, 'temp_min': 71.41, 'temp_max': 71.41, 'sea_level': 1014.34, 'grnd_level': 995.09}
# 3.09
# zhigansk
# {'temp': 50.89, 'pressure': 1021.08, 'humidity': 60, 'temp_min': 50.89, 'temp_max': 50.89, 'sea_level': 1021.08, 'grnd_level': 1007.99}
# 18.03
# los llanos de aridane
# {'temp': 69.35, 'pressure': 1018, 'humidity': 69, 'temp_min': 64.99, 'temp_max': 73.4}
# 18.34
# souillac
# {'temp': 72.63, 'pressure': 1012, 'humidity': 53, 'temp_min': 69.01, 'temp_max': 77}
# 8.05
# kudahuvadhoo
# {'temp': 83.83, 'pressure': 1007.35, 'humidity': 74, 'temp_min': 83.83, 'temp_max': 83.83, 'sea_level': 1007.35, 'grnd_level': 1007.36}
# 18.66
# louisbourg
# City not found. Skipping..
# barentsburg
# City not found. Skipping..
# ilulissat
# {'temp': 50, 'pressure': 1013, 'humidity': 81, 'temp_min': 50, 'temp_max': 50}
# 3.36
# ilebo
# {'temp': 73.21, 'pressure': 1011.1, 'humidity': 27, 'temp_min': 73.21, 'temp_max': 73.21, 'sea_level': 1011.1, 'grnd_level': 956.12}
# 1.68
# tual
# {'temp': 77.17, 'pressure': 1010.89, 'humidity': 85, 'temp_min': 77.17, 'temp_max': 77.17, 'sea_level': 1010.89, 'grnd_level': 1010.9}
# 18.57
# vostok
# {'temp': 64.57, 'pressure': 1010.74, 'humidity': 95, 'temp_min': 64.57, 'temp_max': 64.57, 'sea_level': 1010.74, 'grnd_level': 962.82}
# 2.35
# lumatil
# {'temp': 77.35, 'pressure': 1009.44, 'humidity': 84, 'temp_min': 77.35, 'temp_max': 77.35, 'sea_level': 1009.44, 'grnd_level': 1000.1}
# 5.01
# mount isa
# {'temp': 35.6, 'pressure': 1018, 'humidity': 59, 'temp_min': 35.6, 'temp_max': 35.6}
# 10.89
# moron
# {'temp': 82.75, 'pressure': 1013.06, 'humidity': 69, 'temp_min': 82.75, 'temp_max': 82.75, 'sea_level': 1013.06, 'grnd_level': 1006.23}
# 2.17
# waipawa
# {'temp': 48.99, 'pressure': 1000, 'humidity': 95, 'temp_min': 48.99, 'temp_max': 48.99}
# 4
# chebarkul
# {'temp': 64.21, 'pressure': 1010.14, 'humidity': 91, 'temp_min': 64.21, 'temp_max': 64.21, 'sea_level': 1010.14, 'grnd_level': 962.4}
# 4.34
# dunedin
# {'temp': 48, 'pressure': 1002, 'humidity': 96, 'temp_min': 48, 'temp_max': 48}
# 13.15
# kaitangata
# {'temp': 48, 'pressure': 1003, 'humidity': 88, 'temp_min': 48, 'temp_max': 48}
# 7
# samusu
# City not found. Skipping..
# stornoway
# City not found. Skipping..
# cherskiy
# {'temp': 39.55, 'pressure': 1015.7, 'humidity': 79, 'temp_min': 39.55, 'temp_max': 39.55, 'sea_level': 1015.7, 'grnd_level': 1015.16}
# 9.4
# deep river
# {'temp': 90, 'pressure': 1005, 'humidity': 52, 'temp_min': 87.8, 'temp_max': 91.99}
# 6.93
# flinders
# {'temp': 43.36, 'pressure': 1021, 'humidity': 75, 'temp_min': 37, 'temp_max': 46.99}
# 11.41
# lata
# {'temp': 40.63, 'pressure': 1010.57, 'humidity': 83, 'temp_min': 40.63, 'temp_max': 40.63, 'sea_level': 1010.57, 'grnd_level': 633.73}
# 2.95
# ploemeur
# {'temp': 66.83, 'pressure': 1012, 'humidity': 88, 'temp_min': 66, 'temp_max': 68}
# 9.17
# bara
# {'temp': 71.77, 'pressure': 1013.73, 'humidity': 93, 'temp_min': 71.77, 'temp_max': 71.77, 'sea_level': 1013.73, 'grnd_level': 966.08}
# 4.03
# safwah
# City not found. Skipping..
# talnakh
# {'temp': 59, 'pressure': 1020, 'humidity': 54, 'temp_min': 59, 'temp_max': 59}
# 8.95
# zhangjiakou
# {'temp': 62.41, 'pressure': 1004.67, 'humidity': 88, 'temp_min': 62.41, 'temp_max': 62.41, 'sea_level': 1004.67, 'grnd_level': 848.98}
# 3.13
# tiksi
# {'temp': 44.05, 'pressure': 1020.92, 'humidity': 67, 'temp_min': 44.05, 'temp_max': 44.05, 'sea_level': 1020.92, 'grnd_level': 1008.72}
# 5.19
# acarau
# City not found. Skipping..
# iracoubo
# {'temp': 78.43, 'pressure': 1011.57, 'humidity': 89, 'temp_min': 78.43, 'temp_max': 78.43, 'sea_level': 1011.57, 'grnd_level': 1007.25}
# 5.75
# koumac
# {'temp': 69.97, 'pressure': 1017.47, 'humidity': 64, 'temp_min': 69.97, 'temp_max': 69.97, 'sea_level': 1017.47, 'grnd_level': 1017.43}
# 11.68
# lima
# {'temp': 62.6, 'pressure': 1011, 'humidity': 82, 'temp_min': 62.6, 'temp_max': 62.6}
# 6.93
# islamabad
# {'temp': 81, 'pressure': 1006, 'humidity': 70, 'temp_min': 81, 'temp_max': 81}
# 1.01
# canto do buriti
# {'temp': 76.27, 'pressure': 1015.58, 'humidity': 52, 'temp_min': 76.27, 'temp_max': 76.27, 'sea_level': 1015.58, 'grnd_level': 972.28}
# 7.85
# irbit
# {'temp': 64.93, 'pressure': 1009.1, 'humidity': 96, 'temp_min': 64.93, 'temp_max': 64.93, 'sea_level': 1009.1, 'grnd_level': 996.79}
# 6.4
# klyuchi
# {'temp': 64.21, 'pressure': 1007.51, 'humidity': 72, 'temp_min': 64.21, 'temp_max': 64.21, 'sea_level': 1007.51, 'grnd_level': 991.91}
# 4.81
# karasjok
# {'temp': 60.8, 'pressure': 1013, 'humidity': 72, 'temp_min': 60.8, 'temp_max': 60.8}
# 16.11
# pevek
# {'temp': 32.53, 'pressure': 1013.27, 'humidity': 98, 'temp_min': 32.53, 'temp_max': 32.53, 'sea_level': 1013.27, 'grnd_level': 1013.4}
# 7.27
# ussel
# {'temp': 61.51, 'pressure': 1013.33, 'humidity': 66, 'temp_min': 61.51, 'temp_max': 61.51, 'sea_level': 1013.33, 'grnd_level': 931.81}
# 1.74
# yanam
# {'temp': 79.87, 'pressure': 1000.37, 'humidity': 86, 'temp_min': 79.87, 'temp_max': 79.87, 'sea_level': 1000.37, 'grnd_level': 996.74}
# 1.12
# caravelas
# {'temp': 70.51, 'pressure': 1023.68, 'humidity': 77, 'temp_min': 70.51, 'temp_max': 70.51, 'sea_level': 1023.68, 'grnd_level': 1022.39}
# 13.91
# saint-philippe
# {'temp': 88.54, 'pressure': 1006, 'humidity': 59, 'temp_min': 84.99, 'temp_max': 91.4}
# 3.36
# beloha
# {'temp': 63.13, 'pressure': 1017.52, 'humidity': 85, 'temp_min': 63.13, 'temp_max': 63.13, 'sea_level': 1017.52, 'grnd_level': 995.56}
# 4.32
# kipushi
# {'temp': 54.13, 'pressure': 1018.53, 'humidity': 53, 'temp_min': 54.13, 'temp_max': 54.13, 'sea_level': 1018.53, 'grnd_level': 868.58}
# 1.21
# cazaje
# City not found. Skipping..
# teguise
# {'temp': 73.4, 'pressure': 1015, 'humidity': 78, 'temp_min': 73.4, 'temp_max': 73.4}
# 17.22
# gbarnga
# {'temp': 71.23, 'pressure': 1014.61, 'humidity': 98, 'temp_min': 71.23, 'temp_max': 71.23, 'sea_level': 1014.61, 'grnd_level': 983.72}
# 4.65
# nanortalik
# {'temp': 44.41, 'pressure': 1012.3, 'humidity': 92, 'temp_min': 44.41, 'temp_max': 44.41, 'sea_level': 1012.3, 'grnd_level': 1004.29}
# 3.94
# isla mujeres
# {'temp': 87.42, 'pressure': 1016, 'humidity': 70, 'temp_min': 87.01, 'temp_max': 87.8}
# 8.05
# matay
# {'temp': 82.03, 'pressure': 1011.93, 'humidity': 48, 'temp_min': 82.03, 'temp_max': 82.03, 'sea_level': 1011.93, 'grnd_level': 999.2}
# 19.22
# faya
# {'temp': 78.93, 'pressure': 1022, 'humidity': 19, 'temp_min': 75.2, 'temp_max': 82.4}
# 4.7
# kodiak
# {'temp': 95.52, 'pressure': 1009, 'humidity': 19, 'temp_min': 93, 'temp_max': 98.01}
# 16.11
# cayenne
# {'temp': 75.2, 'pressure': 1012, 'humidity': 88, 'temp_min': 75.2, 'temp_max': 75.2}
# 4.7
# vrangel
# {'temp': 64.93, 'pressure': 1010.41, 'humidity': 96, 'temp_min': 64.93, 'temp_max': 64.93, 'sea_level': 1010.41, 'grnd_level': 982.77}
# 2.64
# saint-augustin
# {'temp': 88.47, 'pressure': 1005, 'humidity': 62, 'temp_min': 86, 'temp_max': 91}
# 9.17
# danane
# {'temp': 69.97, 'pressure': 1014.54, 'humidity': 97, 'temp_min': 69.97, 'temp_max': 69.97, 'sea_level': 1014.54, 'grnd_level': 954.36}
# 6.55
# leh
# {'temp': 41.53, 'pressure': 1021.69, 'humidity': 54, 'temp_min': 41.53, 'temp_max': 41.53, 'sea_level': 1021.69, 'grnd_level': 585.96}
# 1.66
# okhotsk
# {'temp': 53.77, 'pressure': 1007.59, 'humidity': 89, 'temp_min': 53.77, 'temp_max': 53.77, 'sea_level': 1007.59, 'grnd_level': 1003.4}
# 5.32
# mpika
# {'temp': 54.85, 'pressure': 1017.91, 'humidity': 59, 'temp_min': 54.85, 'temp_max': 54.85, 'sea_level': 1017.91, 'grnd_level': 873.75}
# 5.73
# hofn
# {'temp': 40.45, 'pressure': 1003.84, 'humidity': 96, 'temp_min': 40.45, 'temp_max': 40.45, 'sea_level': 1003.84, 'grnd_level': 910.21}
# 11.7
# ponta do sol
# {'temp': 58.81, 'pressure': 1022.24, 'humidity': 61, 'temp_min': 58.81, 'temp_max': 58.81, 'sea_level': 1022.24, 'grnd_level': 912.87}
# 5.79
# san vicente
# {'temp': 73.03, 'pressure': 1006.8, 'humidity': 83, 'temp_min': 73.03, 'temp_max': 73.03, 'sea_level': 1006.8, 'grnd_level': 1003.3}
# 10.18
# sovkhoznyy
# {'temp': 61.11, 'pressure': 1017, 'humidity': 93, 'temp_min': 57.2, 'temp_max': 66.99}
# 4.47
# sentyabrskiy
# City not found. Skipping..
# lebu
# {'temp': 54.13, 'pressure': 1016.57, 'humidity': 95, 'temp_min': 54.13, 'temp_max': 54.13, 'sea_level': 1016.57, 'grnd_level': 772.12}
# 1.72
# acapulco
# {'temp': 87.8, 'pressure': 1012, 'humidity': 66, 'temp_min': 87.8, 'temp_max': 87.8}
# 6.93
# adrar
# {'temp': 109.4, 'pressure': 1006, 'humidity': 12, 'temp_min': 109.4, 'temp_max': 109.4}
# 13.87
# norman wells
# {'temp': 77, 'pressure': 1009, 'humidity': 53, 'temp_min': 77, 'temp_max': 77}
# 4.7
# belushya guba
# City not found. Skipping..
# portland
# {'temp': 81.45, 'pressure': 1008, 'humidity': 61, 'temp_min': 71.01, 'temp_max': 91}
# 8.05
# illela
# {'temp': 83.83, 'pressure': 1010.91, 'humidity': 66, 'temp_min': 83.83, 'temp_max': 83.83, 'sea_level': 1010.91, 'grnd_level': 984.08}
# 9.08
# shingu
# {'temp': 68.17, 'pressure': 1015.3, 'humidity': 96, 'temp_min': 68.17, 'temp_max': 68.17, 'sea_level': 1015.3, 'grnd_level': 943.01}
# 4.88
# damaturu
# {'temp': 80.41, 'pressure': 1012.51, 'humidity': 67, 'temp_min': 80.41, 'temp_max': 80.41, 'sea_level': 1012.51, 'grnd_level': 969.3}
# 10.89
# kaspiyskiy
# {'temp': 85.27, 'pressure': 1012.62, 'humidity': 36, 'temp_min': 85.27, 'temp_max': 85.27, 'sea_level': 1012.62, 'grnd_level': 1015.2}
# 7
# sironj
# {'temp': 86.35, 'pressure': 1000.68, 'humidity': 54, 'temp_min': 86.35, 'temp_max': 86.35, 'sea_level': 1000.68, 'grnd_level': 945.19}
# 4.38
# lompoc
# {'temp': 68.27, 'pressure': 1015, 'humidity': 68, 'temp_min': 62.6, 'temp_max': 73.4}
# 11.41
# skowhegan
# {'temp': 82.47, 'pressure': 1006, 'humidity': 58, 'temp_min': 80.01, 'temp_max': 84.99}
# 10.29
# maloshuyka
# City not found. Skipping..
# leningradskiy
# {'temp': 37.75, 'pressure': 1011.73, 'humidity': 81, 'temp_min': 37.75, 'temp_max': 37.75, 'sea_level': 1011.73, 'grnd_level': 1008.69}
# 7.61
# tilichiki
# {'temp': 53.23, 'pressure': 1016.22, 'humidity': 99, 'temp_min': 53.23, 'temp_max': 53.23, 'sea_level': 1016.22, 'grnd_level': 1003.76}
# 4.23
# lahat
# {'temp': 67.09, 'pressure': 1008.72, 'humidity': 87, 'temp_min': 67.09, 'temp_max': 67.09, 'sea_level': 1008.72, 'grnd_level': 931.14}
# 2.84
# codrington
# {'temp': 47.08, 'pressure': 1024, 'humidity': 93, 'temp_min': 41, 'temp_max': 55.99}
# 6.93
# namie
# {'temp': 71.92, 'pressure': 1014, 'humidity': 94, 'temp_min': 70, 'temp_max': 73.99}
# 1.12
# quijingue
# {'temp': 70.51, 'pressure': 1019.5, 'humidity': 64, 'temp_min': 70.51, 'temp_max': 70.51, 'sea_level': 1019.5, 'grnd_level': 983.38}
# 7.14
# corinth
# {'temp': 76.24, 'pressure': 1013, 'humidity': 36, 'temp_min': 69.01, 'temp_max': 81}
# 3.36
# fukue
# {'temp': 75.87, 'pressure': 1014, 'humidity': 94, 'temp_min': 75, 'temp_max': 78.01}
# 4.7
# necochea
# {'temp': 52, 'pressure': 1013, 'humidity': 80, 'temp_min': 52, 'temp_max': 52}
# 4
# kuche
# City not found. Skipping..
# bongandanga
# {'temp': 75.73, 'pressure': 1011.9, 'humidity': 68, 'temp_min': 75.73, 'temp_max': 75.73, 'sea_level': 1011.9, 'grnd_level': 967.51}
# 1.97
# uri
# {'temp': 56.83, 'pressure': 1005.32, 'humidity': 87, 'temp_min': 56.83, 'temp_max': 56.83, 'sea_level': 1005.32, 'grnd_level': 779.94}
# 3.53
# lavrentiya
# {'temp': 55.57, 'pressure': 1012.81, 'humidity': 74, 'temp_min': 55.57, 'temp_max': 55.57, 'sea_level': 1012.81, 'grnd_level': 973.56}
# 7.74
# komsomolskiy
# {'temp': 57.01, 'pressure': 1009.22, 'humidity': 92, 'temp_min': 57.01, 'temp_max': 57.01, 'sea_level': 1009.22, 'grnd_level': 988.68}
# 10.22
# katsuura
# {'temp': 75.69, 'pressure': 1013, 'humidity': 94, 'temp_min': 75, 'temp_max': 77}
# 16.11
# ancud
# {'temp': 46.4, 'pressure': 1010, 'humidity': 75, 'temp_min': 46.4, 'temp_max': 46.4}
# 9.17
# baoding
# {'temp': 76.63, 'pressure': 1002.74, 'humidity': 70, 'temp_min': 76.63, 'temp_max': 76.63, 'sea_level': 1002.74, 'grnd_level': 963.67}
# 2.48
# vizinga
# {'temp': 56.11, 'pressure': 1008.34, 'humidity': 69, 'temp_min': 56.11, 'temp_max': 56.11, 'sea_level': 1008.34, 'grnd_level': 989.92}
# 4.12
# iqaluit
# {'temp': 51.39, 'pressure': 1004, 'humidity': 76, 'temp_min': 51.01, 'temp_max': 51.8}
# 6.93
# kavaratti
# {'temp': 80.05, 'pressure': 1006.1, 'humidity': 82, 'temp_min': 80.05, 'temp_max': 80.05, 'sea_level': 1006.1, 'grnd_level': 1006.45}
# 23.53
# mahibadhoo
# {'temp': 83.47, 'pressure': 1007.06, 'humidity': 77, 'temp_min': 83.47, 'temp_max': 83.47, 'sea_level': 1007.06, 'grnd_level': 1007.2}
# 18.77
# faanui
# {'temp': 76.99, 'pressure': 1014.59, 'humidity': 73, 'temp_min': 76.99, 'temp_max': 76.99, 'sea_level': 1014.59, 'grnd_level': 1014.64}
# 13.44
# axim
# {'temp': 76.09, 'pressure': 1014.84, 'humidity': 91, 'temp_min': 76.09, 'temp_max': 76.09, 'sea_level': 1014.84, 'grnd_level': 1012.72}
# 7.52
# inongo
# {'temp': 76.09, 'pressure': 1011.92, 'humidity': 74, 'temp_min': 76.09, 'temp_max': 76.09, 'sea_level': 1011.92, 'grnd_level': 975.12}
# 3.09
# tuy hoa
# {'temp': 75.73, 'pressure': 1005.9, 'humidity': 87, 'temp_min': 75.73, 'temp_max': 75.73, 'sea_level': 1005.9, 'grnd_level': 982.2}
# 4.59
# kytlym
# City not found. Skipping..
# moravsky krumlov
# {'temp': 62.56, 'pressure': 1017, 'humidity': 88, 'temp_min': 59, 'temp_max': 66}
# 4.7
# yulara
# {'temp': 35.6, 'pressure': 1016, 'humidity': 40, 'temp_min': 35.6, 'temp_max': 35.6}
# 7.61
# kaka
# {'temp': 92.29, 'pressure': 1007.26, 'humidity': 15, 'temp_min': 92.29, 'temp_max': 92.29, 'sea_level': 1007.26, 'grnd_level': 977.06}
# 3.91
# grand river south east
# City not found. Skipping..
# yeppoon
# {'temp': 44.6, 'pressure': 1020, 'humidity': 75, 'temp_min': 44.6, 'temp_max': 44.6}
# 4.7
# alihe
# {'temp': 63.67, 'pressure': 1001.63, 'humidity': 99, 'temp_min': 63.67, 'temp_max': 63.67, 'sea_level': 1001.63, 'grnd_level': 932.8}
# 1.03
# husavik
# {'temp': 77.47, 'pressure': 1004, 'humidity': 28, 'temp_min': 77, 'temp_max': 78.01}
# 14
# marcona
# City not found. Skipping..
# nacala
# {'temp': 64.03, 'pressure': 1017.9, 'humidity': 90, 'temp_min': 64.03, 'temp_max': 64.03, 'sea_level': 1017.9, 'grnd_level': 1005.24}
# 2.15
# san rafael del sur
# {'temp': 86, 'pressure': 1009, 'humidity': 74, 'temp_min': 86, 'temp_max': 86}
# 16.11
# anadyr
# {'temp': 59, 'pressure': 1010, 'humidity': 82, 'temp_min': 59, 'temp_max': 59}
# 11.18
# brae
# {'temp': 57.2, 'pressure': 1005, 'humidity': 87, 'temp_min': 57.2, 'temp_max': 57.2}
# 14.99
# buraydah
# {'temp': 91.4, 'pressure': 1008, 'humidity': 27, 'temp_min': 91.4, 'temp_max': 91.4}
# 8.05
# margate
# {'temp': 39.97, 'pressure': 1015, 'humidity': 81, 'temp_min': 37, 'temp_max': 42.8}
# 13.87
# taoudenni
# {'temp': 102.01, 'pressure': 1004.36, 'humidity': 10, 'temp_min': 102.01, 'temp_max': 102.01, 'sea_level': 1004.36, 'grnd_level': 983.2}
# 5.41
# qurbus
# {'temp': 77, 'pressure': 1016, 'humidity': 73, 'temp_min': 77, 'temp_max': 77}
# 5.82
# nalut
# {'temp': 73.57, 'pressure': 1015.13, 'humidity': 53, 'temp_min': 73.57, 'temp_max': 73.57, 'sea_level': 1015.13, 'grnd_level': 963.54}
# 18.21
# pakxan
# {'temp': 75.19, 'pressure': 1005.33, 'humidity': 93, 'temp_min': 75.19, 'temp_max': 75.19, 'sea_level': 1005.33, 'grnd_level': 954.53}
# 0.74
# kahului
# {'temp': 81.82, 'pressure': 1016, 'humidity': 52, 'temp_min': 77, 'temp_max': 87.8}
# 18.34
# cosamaloapan
# {'temp': 81, 'pressure': 1007, 'humidity': 79, 'temp_min': 81, 'temp_max': 81}
# 4
# kuopio
# {'temp': 62.6, 'pressure': 1011, 'humidity': 77, 'temp_min': 62.6, 'temp_max': 62.6}
# 3.36
# mihona
# {'temp': 93.73, 'pressure': 999.41, 'humidity': 47, 'temp_min': 93.73, 'temp_max': 93.73, 'sea_level': 999.41, 'grnd_level': 981.72}
# 1.07
# carnarvon
# {'temp': 40.27, 'pressure': 1024.05, 'humidity': 81, 'temp_min': 40.27, 'temp_max': 40.27, 'sea_level': 1024.05, 'grnd_level': 874.39}
# 16.75
# les cayes
# {'temp': 83.47, 'pressure': 1012.67, 'humidity': 78, 'temp_min': 83.47, 'temp_max': 83.47, 'sea_level': 1012.67, 'grnd_level': 1012}
# 18.12
# aswan
# {'temp': 96.07, 'pressure': 1008.21, 'humidity': 14, 'temp_min': 96.07, 'temp_max': 96.07, 'sea_level': 1008.21, 'grnd_level': 976}
# 14.05
# coquimbo
# {'temp': 62.6, 'pressure': 1012, 'humidity': 63, 'temp_min': 62.6, 'temp_max': 62.6}
# 9.17
# batticaloa
# {'temp': 78.25, 'pressure': 1003.96, 'humidity': 72, 'temp_min': 78.25, 'temp_max': 78.25, 'sea_level': 1003.96, 'grnd_level': 993.57}
# 5.17
# qasigiannguit
# {'temp': 50, 'pressure': 1013, 'humidity': 81, 'temp_min': 50, 'temp_max': 50}
# 3.36
# talaya
# {'temp': 62.2, 'pressure': 1007, 'humidity': 100, 'temp_min': 62.01, 'temp_max': 62.6}
# 2.24
# umm lajj
# {'temp': 86.71, 'pressure': 1005.44, 'humidity': 74, 'temp_min': 86.71, 'temp_max': 86.71, 'sea_level': 1005.44, 'grnd_level': 1005.49}
# 13.02
# dubti
# {'temp': 93.91, 'pressure': 1006.69, 'humidity': 31, 'temp_min': 93.91, 'temp_max': 93.91, 'sea_level': 1006.69, 'grnd_level': 962.05}
# 5.86
# winneba
# {'temp': 77, 'pressure': 1014, 'humidity': 94, 'temp_min': 77, 'temp_max': 77}
# 12.75
# sikasso
# {'temp': 71.41, 'pressure': 1013.37, 'humidity': 89, 'temp_min': 71.41, 'temp_max': 71.41, 'sea_level': 1013.37, 'grnd_level': 965.7}
# 2.26
# carlsbad
# {'temp': 61.5, 'pressure': 1017, 'humidity': 87, 'temp_min': 57, 'temp_max': 64.4}
# 4.36
# taltal
# {'temp': 63.31, 'pressure': 1011.85, 'humidity': 52, 'temp_min': 63.31, 'temp_max': 63.31, 'sea_level': 1011.85, 'grnd_level': 964.63}
# 3.11
# simplicio mendes
# {'temp': 75.55, 'pressure': 1016.44, 'humidity': 55, 'temp_min': 75.55, 'temp_max': 75.55, 'sea_level': 1016.44, 'grnd_level': 981.12}
# 6.55
# kashi
# City not found. Skipping..
# havoysund
# {'temp': 60.3, 'pressure': 1011, 'humidity': 59, 'temp_min': 57.2, 'temp_max': 64.4}
# 9.17
# byron bay
# {'temp': 44.94, 'pressure': 1023, 'humidity': 87, 'temp_min': 41, 'temp_max': 48.99}
# 5.82
# qaqortoq
# {'temp': 62.6, 'pressure': 1011, 'humidity': 55, 'temp_min': 62.6, 'temp_max': 62.6}
# 9.17
# san patricio
# {'temp': 66.01, 'pressure': 1016.78, 'humidity': 91, 'temp_min': 66.01, 'temp_max': 66.01, 'sea_level': 1016.78, 'grnd_level': 1003.25}
# 4.63
# baruun-urt
# {'temp': 62.77, 'pressure': 997.25, 'humidity': 90, 'temp_min': 62.77, 'temp_max': 62.77, 'sea_level': 997.25, 'grnd_level': 875.4}
# 11.32
# hasaki
# {'temp': 75.49, 'pressure': 1014, 'humidity': 88, 'temp_min': 75, 'temp_max': 77}
# 1.12
# constitucion
# {'temp': 76.46, 'pressure': 1022, 'humidity': 36, 'temp_min': 75.2, 'temp_max': 78.01}
# 3.36
# kalmunai
# {'temp': 78.25, 'pressure': 1003.96, 'humidity': 72, 'temp_min': 78.25, 'temp_max': 78.25, 'sea_level': 1003.96, 'grnd_level': 993.57}
# 5.17
# gat
# {'temp': 77, 'pressure': 1012, 'humidity': 69, 'temp_min': 77, 'temp_max': 77}
# 10.29
# guaratinga
# City not found. Skipping..
# chernyshevskiy
# {'temp': 46.75, 'pressure': 1022.08, 'humidity': 76, 'temp_min': 46.75, 'temp_max': 46.75, 'sea_level': 1022.08, 'grnd_level': 983.41}
# 4.68
# bembereke
# {'temp': 74.47, 'pressure': 1012.62, 'humidity': 87, 'temp_min': 74.47, 'temp_max': 74.47, 'sea_level': 1012.62, 'grnd_level': 975.52}
# 4.43
# tuatapere
# {'temp': 46, 'pressure': 1008, 'humidity': 97, 'temp_min': 46, 'temp_max': 46}
# 5.99
# sao joao da barra
# {'temp': 70.74, 'pressure': 1025, 'humidity': 68, 'temp_min': 69.8, 'temp_max': 71.6}
# 10.29
# ballina
# {'temp': 58.42, 'pressure': 998, 'humidity': 100, 'temp_min': 57, 'temp_max': 60.01}
# 5.82
# satitoa
# City not found. Skipping..
# aurillac
# {'temp': 71.11, 'pressure': 1016, 'humidity': 56, 'temp_min': 68, 'temp_max': 73.4}
# 3.36
# kingsport
# {'temp': 88.41, 'pressure': 1018, 'humidity': 58, 'temp_min': 82.99, 'temp_max': 91.99}
# 6.93
# dawlatabad
# {'temp': 86.35, 'pressure': 1002.96, 'humidity': 11, 'temp_min': 86.35, 'temp_max': 86.35, 'sea_level': 1002.96, 'grnd_level': 933.68}
# 16.98
# shimoda
# {'temp': 73.87, 'pressure': 1010, 'humidity': 95, 'temp_min': 72, 'temp_max': 75.99}
# 5.1
# le vauclin
# {'temp': 83.62, 'pressure': 1015, 'humidity': 70, 'temp_min': 81, 'temp_max': 86}
# 16.11
# buala
# {'temp': 79.33, 'pressure': 1010.09, 'humidity': 83, 'temp_min': 79.33, 'temp_max': 79.33, 'sea_level': 1010.09, 'grnd_level': 1001.28}
# 8.12
# erenhot
# {'temp': 70.51, 'pressure': 1000.18, 'humidity': 57, 'temp_min': 70.51, 'temp_max': 70.51, 'sea_level': 1000.18, 'grnd_level': 886.72}
# 7.65
# tingrela
# City not found. Skipping..
# bibai
# {'temp': 68.45, 'pressure': 1015, 'humidity': 100, 'temp_min': 66.2, 'temp_max': 69.01}
# 6.93
# rocha
# {'temp': 56.29, 'pressure': 1016.57, 'humidity': 91, 'temp_min': 56.29, 'temp_max': 56.29, 'sea_level': 1016.57, 'grnd_level': 1003.22}
# 4.61
# la gaulette
# City not found. Skipping..
# phan thiet
# {'temp': 74.65, 'pressure': 1007, 'humidity': 92, 'temp_min': 74.65, 'temp_max': 74.65, 'sea_level': 1007, 'grnd_level': 990.77}
# 3.91
# teahupoo
# {'temp': 80.26, 'pressure': 1014, 'humidity': 57, 'temp_min': 80.01, 'temp_max': 80.6}
# 3.36
# iberia
# {'temp': 89.95, 'pressure': 1009.7, 'humidity': 38, 'temp_min': 89.95, 'temp_max': 89.95, 'sea_level': 1009.7, 'grnd_level': 974.76}
# 1.52
# olafsvik
# City not found. Skipping..
# gladstone
# {'temp': 52.68, 'pressure': 1021, 'humidity': 81, 'temp_min': 50, 'temp_max': 55}
# 8.05
# thunder bay
# {'temp': 78.64, 'pressure': 1005, 'humidity': 57, 'temp_min': 77, 'temp_max': 81}
# 9.17
# gazanjyk
# {'temp': 88.69, 'pressure': 1007.25, 'humidity': 43, 'temp_min': 88.69, 'temp_max': 88.69, 'sea_level': 1007.25, 'grnd_level': 1004.74}
# 19.04
# vadum
# {'temp': 60.62, 'pressure': 1014, 'humidity': 86, 'temp_min': 59, 'temp_max': 62.01}
# 7.83
# spirit river
# {'temp': 65.43, 'pressure': 1013, 'humidity': 82, 'temp_min': 62.6, 'temp_max': 68}
# 9.17
# laguna
# {'temp': 86, 'pressure': 1013, 'humidity': 70, 'temp_min': 86, 'temp_max': 86}
# 6.93
# tamale
# {'temp': 73.21, 'pressure': 1012.61, 'humidity': 93, 'temp_min': 73.21, 'temp_max': 73.21, 'sea_level': 1012.61, 'grnd_level': 995.81}
# 4.85
# pangnirtung
# {'temp': 50, 'pressure': 1005, 'humidity': 93, 'temp_min': 50, 'temp_max': 50}
# 2.24
# kegayli
# City not found. Skipping..
# geraldton
# {'temp': 82.4, 'pressure': 1004, 'humidity': 39, 'temp_min': 82.4, 'temp_max': 82.4}
# 20.8
# ekibastuz
# {'temp': 65.83, 'pressure': 1009.69, 'humidity': 59, 'temp_min': 65.83, 'temp_max': 65.83, 'sea_level': 1009.69, 'grnd_level': 990.02}
# 6.58
# zemio
# {'temp': 69.61, 'pressure': 1012.94, 'humidity': 91, 'temp_min': 69.61, 'temp_max': 69.61, 'sea_level': 1012.94, 'grnd_level': 944.72}
# 1.12
# campbell river
# {'temp': 63.37, 'pressure': 1021, 'humidity': 59, 'temp_min': 62.6, 'temp_max': 64.4}
# 4.7
# wanaka
# {'temp': 35.05, 'pressure': 1002.66, 'humidity': 97, 'temp_min': 35.05, 'temp_max': 35.05, 'sea_level': 1002.66, 'grnd_level': 902.48}
# 3.11
# kuala terengganu
# {'temp': 78.8, 'pressure': 1007, 'humidity': 94, 'temp_min': 78.8, 'temp_max': 78.8}
# 2.24
# alpinopolis
# {'temp': 56.11, 'pressure': 1022.49, 'humidity': 70, 'temp_min': 56.11, 'temp_max': 56.11, 'sea_level': 1022.49, 'grnd_level': 906.8}
# 3.78
# merauke
# {'temp': 76.45, 'pressure': 1012.76, 'humidity': 80, 'temp_min': 76.45, 'temp_max': 76.45, 'sea_level': 1012.76, 'grnd_level': 1012.76}
# 20.54
# walvis bay
# {'temp': 60.75, 'pressure': 1018, 'humidity': 56, 'temp_min': 57, 'temp_max': 68}
# 2.24
# sysert
# {'temp': 66.2, 'pressure': 1008, 'humidity': 88, 'temp_min': 66.2, 'temp_max': 66.2}
# 4.47
# itupiranga
# {'temp': 91.4, 'pressure': 1013, 'humidity': 41, 'temp_min': 91.4, 'temp_max': 91.4}
# 5.82
# pisco
# {'temp': 67.1, 'pressure': 1012, 'humidity': 30, 'temp_min': 63, 'temp_max': 71.6}
# 5.82
# goma
# {'temp': 57.55, 'pressure': 1016.06, 'humidity': 93, 'temp_min': 57.55, 'temp_max': 57.55, 'sea_level': 1016.06, 'grnd_level': 802.45}
# 1.32
# luderitz
# {'temp': 58.09, 'pressure': 1021.39, 'humidity': 80, 'temp_min': 58.09, 'temp_max': 58.09, 'sea_level': 1021.39, 'grnd_level': 1019.09}
# 27.94
# newport
# {'temp': 62.19, 'pressure': 1007, 'humidity': 93, 'temp_min': 60.01, 'temp_max': 64.4}
# 9.17
# baherden
# {'temp': 83.83, 'pressure': 1008.18, 'humidity': 25, 'temp_min': 83.83, 'temp_max': 83.83, 'sea_level': 1008.18, 'grnd_level': 902.6}
# 0.4
# attawapiskat
# City not found. Skipping..
# bonavista
# {'temp': 55, 'pressure': 1000, 'humidity': 83, 'temp_min': 55, 'temp_max': 55}
# 1.99
# port hedland
# {'temp': 60.8, 'pressure': 1014, 'humidity': 100, 'temp_min': 60.8, 'temp_max': 60.8}
# 4.7
# touros
# {'temp': 77, 'pressure': 1015, 'humidity': 88, 'temp_min': 77, 'temp_max': 77}
# 6.93
# muros
# {'temp': 65.53, 'pressure': 1016, 'humidity': 73, 'temp_min': 62.01, 'temp_max': 69.8}
# 6.93
# pakwach
# City not found. Skipping..
# cabedelo
# {'temp': 73.4, 'pressure': 1016, 'humidity': 100, 'temp_min': 73.4, 'temp_max': 73.4}
# 17.22
# hearst
# {'temp': 82.39, 'pressure': 1000.26, 'humidity': 42, 'temp_min': 82.39, 'temp_max': 82.39, 'sea_level': 1000.26, 'grnd_level': 979.25}
# 10.42
# guozhen
# {'temp': 77.35, 'pressure': 1001.79, 'humidity': 86, 'temp_min': 77.35, 'temp_max': 77.35, 'sea_level': 1001.79, 'grnd_level': 998.52}
# 3.56
# chumikan
# {'temp': 56.47, 'pressure': 1012.39, 'humidity': 82, 'temp_min': 56.47, 'temp_max': 56.47, 'sea_level': 1012.39, 'grnd_level': 959.51}
# 2.37
# grindavik
# {'temp': 59.32, 'pressure': 1004, 'humidity': 71, 'temp_min': 57.2, 'temp_max': 60.8}
# 12.75
# bacalar
# {'temp': 89.6, 'pressure': 1014, 'humidity': 59, 'temp_min': 89.6, 'temp_max': 89.6}
# 16.11
# kadykchan
# City not found. Skipping..
# tiznit
# {'temp': 68.35, 'pressure': 1013.26, 'humidity': 90, 'temp_min': 68.35, 'temp_max': 68.35, 'sea_level': 1013.26, 'grnd_level': 1013.54}
# 9.53
# upernavik
# {'temp': 44.23, 'pressure': 1011.02, 'humidity': 92, 'temp_min': 44.23, 'temp_max': 44.23, 'sea_level': 1011.02, 'grnd_level': 1011.06}
# 11.95
# huron
# {'temp': 91.13, 'pressure': 1004, 'humidity': 66, 'temp_min': 87.8, 'temp_max': 93.2}
# 13.87
# amapa
# {'temp': 93.2, 'pressure': 1011, 'humidity': 52, 'temp_min': 93.2, 'temp_max': 93.2}
# 18.34
# nizhneyansk
# City not found. Skipping..
# black river
# {'temp': 83.08, 'pressure': 1012, 'humidity': 70, 'temp_min': 80.01, 'temp_max': 87.8}
# 14.99
# kayes
# {'temp': 90.49, 'pressure': 1009.86, 'humidity': 46, 'temp_min': 90.49, 'temp_max': 90.49, 'sea_level': 1009.86, 'grnd_level': 1002.08}
# 7.18
# gogrial
# City not found. Skipping..
# oktyabrskiy
# {'temp': 59.04, 'pressure': 1007, 'humidity': 87, 'temp_min': 57.2, 'temp_max': 61}
# 6.71
# kontagora
# {'temp': 74.65, 'pressure': 1013.45, 'humidity': 84, 'temp_min': 74.65, 'temp_max': 74.65, 'sea_level': 1013.45, 'grnd_level': 981.4}
# 4.47
# nguiu
# City not found. Skipping..
# kostomuksha
# {'temp': 53.23, 'pressure': 1013.29, 'humidity': 87, 'temp_min': 53.23, 'temp_max': 53.23, 'sea_level': 1013.29, 'grnd_level': 996.08}
# 3.24
# luau
# {'temp': 59.89, 'pressure': 1016.77, 'humidity': 35, 'temp_min': 59.89, 'temp_max': 59.89, 'sea_level': 1016.77, 'grnd_level': 897.44}
# 2.71
# thinadhoo
# {'temp': 83.11, 'pressure': 1007.14, 'humidity': 77, 'temp_min': 83.11, 'temp_max': 83.11, 'sea_level': 1007.14, 'grnd_level': 1007.33}
# 16.31
# dauphin
# {'temp': 68, 'pressure': 1003, 'humidity': 60, 'temp_min': 68, 'temp_max': 68}
# 16.11
# jaisalmer
# {'temp': 88.69, 'pressure': 998.1, 'humidity': 51, 'temp_min': 88.69, 'temp_max': 88.69, 'sea_level': 998.1, 'grnd_level': 978.85}
# 16.78
# segou
# ...
# 3.53
# moengo
# {'temp': 78.07, 'pressure': 1011.1, 'humidity': 96, 'temp_min': 78.07, 'temp_max': 78.07, 'sea_level': 1011.1, 'grnd_level': 1007.6}
# 3.24
# koshurnikovo
# {'temp': 53.23, 'pressure': 1005.09, 'humidity': 97, 'temp_min': 53.23, 'temp_max': 53.23, 'sea_level': 1005.09, 'grnd_level': 926.23}
# 2.48
# sola
# {'temp': 72.31, 'pressure': 1013.58, 'humidity': 43, 'temp_min': 72.31, 'temp_max': 72.31, 'sea_level': 1013.58, 'grnd_level': 877.06}
# 4.68
# marsh harbour
# {'temp': 84.55, 'pressure': 1017.69, 'humidity': 68, 'temp_min': 84.55, 'temp_max': 84.55, 'sea_level': 1017.69, 'grnd_level': 1017.75}
# 7.2
# sangin
# {'temp': 85.63, 'pressure': 997.55, 'humidity': 8, 'temp_min': 85.63, 'temp_max': 85.63, 'sea_level': 997.55, 'grnd_level': 894.58}
# 8.23
# khonuu
# City not found. Skipping..
# divnomorskoye
# {'temp': 72.31, 'pressure': 1016.73, 'humidity': 54, 'temp_min': 72.31, 'temp_max': 72.31, 'sea_level': 1016.73, 'grnd_level': 1012.84}
# 11.34
# flin flon
# {'temp': 62.6, 'pressure': 1001, 'humidity': 88, 'temp_min': 62.6, 'temp_max': 62.6}
# 6.93
# saint anthony
# {'temp': 78.37, 'pressure': 1014, 'humidity': 30, 'temp_min': 75.2, 'temp_max': 80.6}
# 21.92
# bodden town
# {'temp': 88.81, 'pressure': 1014, 'humidity': 70, 'temp_min': 88, 'temp_max': 89.6}
# 14.99
# savalou
# {'temp': 73.57, 'pressure': 1013.77, 'humidity': 91, 'temp_min': 73.57, 'temp_max': 73.57, 'sea_level': 1013.77, 'grnd_level': 987.62}
# 3.65
# orotukan
# {'temp': 40.45, 'pressure': 1011.56, 'humidity': 96, 'temp_min': 40.45, 'temp_max': 40.45, 'sea_level': 1011.56, 'grnd_level': 948.47}
# 4.88
# fare
# {'temp': 75.37, 'pressure': 1014.88, 'humidity': 79, 'temp_min': 75.37, 'temp_max': 75.37, 'sea_level': 1014.88, 'grnd_level': 1014.58}
# 21.18
# noormarkku
# {'temp': 59, 'pressure': 1012, 'humidity': 62, 'temp_min': 59, 'temp_max': 59}
# 6.93
# amparafaravola
# {'temp': 54.13, 'pressure': 1020.54, 'humidity': 90, 'temp_min': 54.13, 'temp_max': 54.13, 'sea_level': 1020.54, 'grnd_level': 910.37}
# 3.85
# rungata
# City not found. Skipping..
# derzhavinsk
# {'temp': 76.09, 'pressure': 1010.4, 'humidity': 42, 'temp_min': 76.09, 'temp_max': 76.09, 'sea_level': 1010.4, 'grnd_level': 977.84}
# 8.48
# sibolga
# {'temp': 80.59, 'pressure': 1007.67, 'humidity': 79, 'temp_min': 80.59, 'temp_max': 80.59, 'sea_level': 1007.67, 'grnd_level': 1006.72}
# 3.62
# zachagansk
# City not found. Skipping..
# tautira
# {'temp': 80.26, 'pressure': 1014, 'humidity': 57, 'temp_min': 80.01, 'temp_max': 80.6}
# 3.36
# pangai
# {'temp': 77, 'pressure': 1013, 'humidity': 94, 'temp_min': 77, 'temp_max': 77}
# 10.29
# qinhuangdao
# {'temp': 67.81, 'pressure': 1003.95, 'humidity': 90, 'temp_min': 67.81, 'temp_max': 67.81, 'sea_level': 1003.95, 'grnd_level': 990.24}
# 1.54
# waimana
# {'temp': 50.47, 'pressure': 1004, 'humidity': 97, 'temp_min': 50, 'temp_max': 51.01}
# 2.75
# coruripe
# {'temp': 69.61, 'pressure': 1018.54, 'humidity': 93, 'temp_min': 69.61, 'temp_max': 69.61, 'sea_level': 1018.54, 'grnd_level': 1002.82}
# 7.99
# pokhara
# {'temp': 55.03, 'pressure': 1010.42, 'humidity': 79, 'temp_min': 55.03, 'temp_max': 55.03, 'sea_level': 1010.42, 'grnd_level': 740.29}
# 2.13
# novoagansk
# {'temp': 65.11, 'pressure': 1011.29, 'humidity': 81, 'temp_min': 65.11, 'temp_max': 65.11, 'sea_level': 1011.29, 'grnd_level': 1004.21}
# 2.59
# berlevag
# {'temp': 50.11, 'pressure': 1015, 'humidity': 93, 'temp_min': 48.2, 'temp_max': 53.6}
# 12.75
# tazovskiy
# {'temp': 58.81, 'pressure': 1013.88, 'humidity': 64, 'temp_min': 58.81, 'temp_max': 58.81, 'sea_level': 1013.88, 'grnd_level': 1012.68}
# 12.77
# russkaya polyana
# {'temp': 63.85, 'pressure': 1010.64, 'humidity': 77, 'temp_min': 63.85, 'temp_max': 63.85, 'sea_level': 1010.64, 'grnd_level': 995.83}
# 8.21
# paamiut
# {'temp': 45.31, 'pressure': 1012.79, 'humidity': 89, 'temp_min': 45.31, 'temp_max': 45.31, 'sea_level': 1012.79, 'grnd_level': 1013.35}
# 9.64
# puerto baquerizo moreno
# {'temp': 73.4, 'pressure': 1008, 'humidity': 83, 'temp_min': 73.4, 'temp_max': 73.4}
# 13.87
# katangli
# {'temp': 64.03, 'pressure': 1011.61, 'humidity': 90, 'temp_min': 64.03, 'temp_max': 64.03, 'sea_level': 1011.61, 'grnd_level': 1005.76}
# 5.77
# emerald
# {'temp': 40.86, 'pressure': 1021, 'humidity': 70, 'temp_min': 39, 'temp_max': 42.8}
# 4.7
# villazon
# City not found. Skipping..
# mnogovershinnyy
# {'temp': 59.53, 'pressure': 1011.81, 'humidity': 95, 'temp_min': 59.53, 'temp_max': 59.53, 'sea_level': 1011.81, 'grnd_level': 975.41}
# 5.06
# padre bernardo
# City not found. Skipping..
# kirtipur
# {'temp': 71.6, 'pressure': 1012, 'humidity': 94, 'temp_min': 71.6, 'temp_max': 71.6}
# 3.36
# tabiauea
# City not found. Skipping..
# guatire
# {'temp': 82.47, 'pressure': 1011, 'humidity': 69, 'temp_min': 82, 'temp_max': 82.99}
# 5.82
# cozumel
# City not found. Skipping..
# san cristobal
# {'temp': 84.01, 'pressure': 1010.75, 'humidity': 45, 'temp_min': 84.01, 'temp_max': 84.01, 'sea_level': 1010.75, 'grnd_level': 909.27}
# 11.43
# bandipur
# {'temp': 63.31, 'pressure': 1006.99, 'humidity': 97, 'temp_min': 63.31, 'temp_max': 63.31, 'sea_level': 1006.99, 'grnd_level': 871.91}
# 8.12
# guerrero negro
# {'temp': 64.39, 'pressure': 1011.53, 'humidity': 90, 'temp_min': 64.39, 'temp_max': 64.39, 'sea_level': 1011.53, 'grnd_level': 1012.34}
# 18.28
# dniprorudne
# {'temp': 62.6, 'pressure': 1017, 'humidity': 72, 'temp_min': 62.6, 'temp_max': 62.6}
# 2.24
# yarada
# {'temp': 80.6, 'pressure': 1001, 'humidity': 94, 'temp_min': 80.6, 'temp_max': 80.6}
# 2.24
# mrirt
# City not found. Skipping..
# marv dasht
# City not found. Skipping..
# robertsport
# {'temp': 76.63, 'pressure': 1014.42, 'humidity': 89, 'temp_min': 76.63, 'temp_max': 76.63, 'sea_level': 1014.42, 'grnd_level': 1012.6}
# 14.27
# otane
# {'temp': 48.99, 'pressure': 1000, 'humidity': 95, 'temp_min': 48.99, 'temp_max': 48.99}
# 4
# rovnoye
# {'temp': 67.27, 'pressure': 1014.04, 'humidity': 67, 'temp_min': 67.27, 'temp_max': 67.27, 'sea_level': 1014.04, 'grnd_level': 1007.57}
# 6.35
# kamenka
# {'temp': 59, 'pressure': 1015, 'humidity': 87, 'temp_min': 59, 'temp_max': 59}
# 3.29
# puerto escondido
# {'temp': 89.77, 'pressure': 1010.68, 'humidity': 52, 'temp_min': 89.77, 'temp_max': 89.77, 'sea_level': 1010.68, 'grnd_level': 995.83}
# 8.34
# macaboboni
# City not found. Skipping..
# pocao de pedras
# {'temp': 79.51, 'pressure': 1012.68, 'humidity': 68, 'temp_min': 79.51, 'temp_max': 79.51, 'sea_level': 1012.68, 'grnd_level': 1005.46}
# 2.15
# chauk
# {'temp': 78.07, 'pressure': 1003.7, 'humidity': 83, 'temp_min': 78.07, 'temp_max': 78.07, 'sea_level': 1003.7, 'grnd_level': 973.22}
# 6.38
# carmona
# {'temp': 75, 'pressure': 1011, 'humidity': 29, 'temp_min': 75, 'temp_max': 75}
# 18.01
# ambon
# {'temp': 66.94, 'pressure': 1012, 'humidity': 82, 'temp_min': 66, 'temp_max': 68}
# 5.82
# oksfjord
# {'temp': 64.44, 'pressure': 1011, 'humidity': 59, 'temp_min': 62.6, 'temp_max': 66.2}
# 9.17
# monte carmelo
# {'temp': 65.29, 'pressure': 1019.63, 'humidity': 54, 'temp_min': 65.29, 'temp_max': 65.29, 'sea_level': 1019.63, 'grnd_level': 923.86}
# 4.72
# lyuban
# {'temp': 57.19, 'pressure': 1015.15, 'humidity': 91, 'temp_min': 57.19, 'temp_max': 57.19, 'sea_level': 1015.15, 'grnd_level': 996.32}
# 4.79
# freeport
# {'temp': 89.6, 'pressure': 1019, 'humidity': 59, 'temp_min': 89.6, 'temp_max': 89.6}
# 10.29
# lingyuan
# {'temp': 69.61, 'pressure': 1003.8, 'humidity': 76, 'temp_min': 69.61, 'temp_max': 69.61, 'sea_level': 1003.8, 'grnd_level': 929.14}
# 5.86
# sanchor
# {'temp': 92.29, 'pressure': 1001.22, 'humidity': 45, 'temp_min': 92.29, 'temp_max': 92.29, 'sea_level': 1001.22, 'grnd_level': 995.35}
# 10.18
# pombas
# {'temp': 84.91, 'pressure': 1012.77, 'humidity': 31, 'temp_min': 84.91, 'temp_max': 84.91, 'sea_level': 1012.77, 'grnd_level': 968.4}
# 3.47
# shiraz
# {'temp': 82.4, 'pressure': 1011, 'humidity': 24, 'temp_min': 82.4, 'temp_max': 82.4}
# 4.7
# alta floresta
# {'temp': 95, 'pressure': 1012, 'humidity': 28, 'temp_min': 95, 'temp_max': 95}
# 8.05
# struer
# {'temp': 58.82, 'pressure': 1013, 'humidity': 77, 'temp_min': 55.99, 'temp_max': 62.01}
# 4.7
# nova esperanca
# {'temp': 73.21, 'pressure': 1011.11, 'humidity': 85, 'temp_min': 73.21, 'temp_max': 73.21, 'sea_level': 1011.11, 'grnd_level': 912.72}
# 2.57
# verkhnebakanskiy
# {'temp': 58.46, 'pressure': 1017, 'humidity': 93, 'temp_min': 57.2, 'temp_max': 59}
# 4.47
# port blair
# {'temp': 81.67, 'pressure': 1003.89, 'humidity': 84, 'temp_min': 81.67, 'temp_max': 81.67, 'sea_level': 1003.89, 'grnd_level': 1003.68}
# 14.23
# itarema
# {'temp': 76.99, 'pressure': 1013.7, 'humidity': 72, 'temp_min': 76.99, 'temp_max': 76.99, 'sea_level': 1013.7, 'grnd_level': 1009.56}
# 9.35
# bilibino
# {'temp': 42.07, 'pressure': 1013.87, 'humidity': 61, 'temp_min': 42.07, 'temp_max': 42.07, 'sea_level': 1013.87, 'grnd_level': 930.44}
# 4.29
# xiongshi
# City not found. Skipping..
# yeniseysk
# {'temp': 50.35, 'pressure': 1011.07, 'humidity': 87, 'temp_min': 50.35, 'temp_max': 50.35, 'sea_level': 1011.07, 'grnd_level': 998.13}
# 3.27
# cagayan de tawi-tawi
# City not found. Skipping..
# opuwo
# {'temp': 60.61, 'pressure': 1017.53, 'humidity': 20, 'temp_min': 60.61, 'temp_max': 60.61, 'sea_level': 1017.53, 'grnd_level': 902.18}
# 7.25
# luena
# {'temp': 52.51, 'pressure': 1019.44, 'humidity': 41, 'temp_min': 52.51, 'temp_max': 52.51, 'sea_level': 1019.44, 'grnd_level': 865.49}
# 2.62
# krasnoselkup
# City not found. Skipping..
# berdigestyakh
# {'temp': 45.49, 'pressure': 1017.79, 'humidity': 59, 'temp_min': 45.49, 'temp_max': 45.49, 'sea_level': 1017.79, 'grnd_level': 988.15}
# 4.03
# roura
# {'temp': 75.2, 'pressure': 1012, 'humidity': 88, 'temp_min': 75.2, 'temp_max': 75.2}
# 4.7
# caluquembe
# {'temp': 54.31, 'pressure': 1018.42, 'humidity': 29, 'temp_min': 54.31, 'temp_max': 54.31, 'sea_level': 1018.42, 'grnd_level': 840.21}
# 2.42
# satinka
# {'temp': 59.89, 'pressure': 1012.97, 'humidity': 92, 'temp_min': 59.89, 'temp_max': 59.89, 'sea_level': 1012.97, 'grnd_level': 996.05}
# 7.85
# hammerfest
# {'temp': 63.23, 'pressure': 1011, 'humidity': 59, 'temp_min': 62.6, 'temp_max': 64.4}
# 9.17
# lolua
# City not found. Skipping..
# chamba
# {'temp': 68.17, 'pressure': 1008.15, 'humidity': 77, 'temp_min': 68.17, 'temp_max': 68.17, 'sea_level': 1008.15, 'grnd_level': 863.03}
# 4.47
# great yarmouth
# {'temp': 63.97, 'pressure': 1009, 'humidity': 93, 'temp_min': 62.01, 'temp_max': 66}
# 10.29
# hun
# {'temp': 67.28, 'pressure': 1014, 'humidity': 64, 'temp_min': 64, 'temp_max': 69.8}
# 3.36
# ugoofaaru
# {'temp': 84.01, 'pressure': 1006.62, 'humidity': 78, 'temp_min': 84.01, 'temp_max': 84.01, 'sea_level': 1006.62, 'grnd_level': 1006.8}
# 20.31
# waingapu
# {'temp': 66.91, 'pressure': 1011.4, 'humidity': 85, 'temp_min': 66.91, 'temp_max': 66.91, 'sea_level': 1011.4, 'grnd_level': 979.48}
# 4.32
# san agustin
# {'temp': 73.21, 'pressure': 1010.94, 'humidity': 78, 'temp_min': 73.21, 'temp_max': 73.21, 'sea_level': 1010.94, 'grnd_level': 889.96}
# 5.99
# rawannawi
# City not found. Skipping..
# polunochnoye
# {'temp': 52.15, 'pressure': 1010.91, 'humidity': 96, 'temp_min': 52.15, 'temp_max': 52.15, 'sea_level': 1010.91, 'grnd_level': 979.57}
# 3.67
# neiafu
# {'temp': 77, 'pressure': 1013, 'humidity': 94, 'temp_min': 77, 'temp_max': 77}
# 5.82
# mortka
# {'temp': 64.03, 'pressure': 1011.06, 'humidity': 94, 'temp_min': 64.03, 'temp_max': 64.03, 'sea_level': 1011.06, 'grnd_level': 1003.92}
# 3.51
# voznesenye
# {'temp': 56.11, 'pressure': 1005.42, 'humidity': 98, 'temp_min': 56.11, 'temp_max': 56.11, 'sea_level': 1005.42, 'grnd_level': 997.54}
# 3.74
# half moon bay
# {'temp': 72.34, 'pressure': 1014, 'humidity': 82, 'temp_min': 62.01, 'temp_max': 84.2}
# 14.99
# najran
# {'temp': 86, 'pressure': 1011, 'humidity': 16, 'temp_min': 86, 'temp_max': 86}
# 4.59
# popondetta
# {'temp': 63.85, 'pressure': 1013.09, 'humidity': 95, 'temp_min': 63.85, 'temp_max': 63.85, 'sea_level': 1013.09, 'grnd_level': 901.33}
# 1.63
# grozesti
# {'temp': 68.36, 'pressure': 1017, 'humidity': 72, 'temp_min': 68, 'temp_max': 69.01}
# 3.36
# warqla
# City not found. Skipping..
# jacareacanga
# {'temp': 80.6, 'pressure': 1011, 'humidity': 83, 'temp_min': 80.6, 'temp_max': 80.6}
# 4.7
# poyarkovo
# {'temp': 66.91, 'pressure': 1006.25, 'humidity': 85, 'temp_min': 66.91, 'temp_max': 66.91, 'sea_level': 1006.25, 'grnd_level': 985.2}
# 7.74
# navalcarnero
# {'temp': 89.47, 'pressure': 1013, 'humidity': 23, 'temp_min': 80.01, 'temp_max': 96.8}
# 4.7
# vila
# {'temp': 75.81, 'pressure': 1016, 'humidity': 69, 'temp_min': 70, 'temp_max': 81}
# 3.36
# nador
# {'temp': 76.08, 'pressure': 1011, 'humidity': 83, 'temp_min': 75.2, 'temp_max': 77}
# 4.7
# pemangkat
# City not found. Skipping..
# salaya
# {'temp': 82.93, 'pressure': 1001.57, 'humidity': 78, 'temp_min': 82.93, 'temp_max': 82.93, 'sea_level': 1001.57, 'grnd_level': 1002.16}
# 11.1
# mehamn
# {'temp': 53.06, 'pressure': 1014, 'humidity': 87, 'temp_min': 48.2, 'temp_max': 57.2}
# 9.17
# tamazulapam
# City not found. Skipping..
# podgorenskiy
# {'temp': 59.35, 'pressure': 1015.88, 'humidity': 90, 'temp_min': 59.35, 'temp_max': 59.35, 'sea_level': 1015.88, 'grnd_level': 995.94}
# 6.71
# sambava
# {'temp': 64.39, 'pressure': 1018.31, 'humidity': 91, 'temp_min': 64.39, 'temp_max': 64.39, 'sea_level': 1018.31, 'grnd_level': 997.88}
# 3.94
# tweed
# {'temp': 83.7, 'pressure': 1008, 'humidity': 78, 'temp_min': 80.01, 'temp_max': 88}
# 9.17
# haflong
# {'temp': 73.21, 'pressure': 1004.07, 'humidity': 97, 'temp_min': 73.21, 'temp_max': 73.21, 'sea_level': 1004.07, 'grnd_level': 972.4}
# 2.75
# gimli
# {'temp': 77.47, 'pressure': 1004, 'humidity': 28, 'temp_min': 77, 'temp_max': 78.01}
# 14
# pringsewu
# {'temp': 71.05, 'pressure': 1008.6, 'humidity': 97, 'temp_min': 71.05, 'temp_max': 71.05, 'sea_level': 1008.6, 'grnd_level': 975.01}
# 1.21
# santa cruz
# {'temp': 74.65, 'pressure': 1015.26, 'humidity': 68, 'temp_min': 74.65, 'temp_max': 74.65, 'sea_level': 1015.26, 'grnd_level': 968.6}
# 12.68
# montevideo
# {'temp': 91.42, 'pressure': 1003, 'humidity': 59, 'temp_min': 87.8, 'temp_max': 95}
# 14.99
# lasa
# {'temp': 74.52, 'pressure': 1011, 'humidity': 78, 'temp_min': 69.01, 'temp_max': 77}
# 5.82
# wairoa
# {'temp': 52, 'pressure': 999, 'humidity': 99, 'temp_min': 52, 'temp_max': 52}
# 2.19
# nova granada
# {'temp': 78.8, 'pressure': 1020, 'humidity': 34, 'temp_min': 78.8, 'temp_max': 78.8}
# 6.93
# rangpur
# {'temp': 83.29, 'pressure': 1003.18, 'humidity': 81, 'temp_min': 83.29, 'temp_max': 83.29, 'sea_level': 1003.18, 'grnd_level': 996.4}
# 7.18
# college
# {'temp': 65.82, 'pressure': 1015, 'humidity': 55, 'temp_min': 64.4, 'temp_max': 66.2}
# 12.75
# wooster
# {'temp': 90.43, 'pressure': 1015, 'humidity': 74, 'temp_min': 87.01, 'temp_max': 93.99}
# 10.29
# takoradi
# {'temp': 74.47, 'pressure': 1014.8, 'humidity': 91, 'temp_min': 74.47, 'temp_max': 74.47, 'sea_level': 1014.8, 'grnd_level': 1007.11}
# 3.53
# gumdag
# {'temp': 84.91, 'pressure': 1007.95, 'humidity': 45, 'temp_min': 84.91, 'temp_max': 84.91, 'sea_level': 1007.95, 'grnd_level': 967.6}
# 8.55
# qui nhon
# City not found. Skipping..
# bartica
# {'temp': 82.4, 'pressure': 1011, 'humidity': 83, 'temp_min': 82.4, 'temp_max': 82.4}
# 13.87
# isiro
# {'temp': 67.99, 'pressure': 1013.46, 'humidity': 94, 'temp_min': 67.99, 'temp_max': 67.99, 'sea_level': 1013.46, 'grnd_level': 931.44}
# 2.48
# tessalit
# {'temp': 101.83, 'pressure': 1005.04, 'humidity': 9, 'temp_min': 101.83, 'temp_max': 101.83, 'sea_level': 1005.04, 'grnd_level': 954.18}
# 7.67
# ostashkov
# {'temp': 54.85, 'pressure': 1005.41, 'humidity': 99, 'temp_min': 54.85, 'temp_max': 54.85, 'sea_level': 1005.41, 'grnd_level': 978.68}
# 5.84
# saint-joseph
# {'temp': 72.59, 'pressure': 1016, 'humidity': 78, 'temp_min': 69.01, 'temp_max': 75.2}
# 2.21
# dingle
# {'temp': 73.21, 'pressure': 1008.87, 'humidity': 81, 'temp_min': 73.21, 'temp_max': 73.21, 'sea_level': 1008.87, 'grnd_level': 992.92}
# 2.15
# curitibanos
# {'temp': 57, 'pressure': 921, 'humidity': 99, 'temp_min': 57, 'temp_max': 57}
# 1.01
# north bend
# {'temp': 69.13, 'pressure': 1019, 'humidity': 63, 'temp_min': 64, 'temp_max': 77}
# 26.4
# formoso do araguaia
# City not found. Skipping..
# verkhnyaya inta
# {'temp': 54.67, 'pressure': 1009.59, 'humidity': 89, 'temp_min': 54.67, 'temp_max': 54.67, 'sea_level': 1009.59, 'grnd_level': 1002.21}
# 6.82
# morehead
# {'temp': 89.17, 'pressure': 1017, 'humidity': 59, 'temp_min': 87.01, 'temp_max': 91.4}
# 10.29
# kamenskoye
# City not found. Skipping..
# henderson
# {'temp': 100.58, 'pressure': 1009, 'humidity': 7, 'temp_min': 98.01, 'temp_max': 104}
# 14.99

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#XXX = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
#YYY = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

plt.scatter(XXX, YYY, marker="o", facecolors="blue", edgecolors="black")

plt.ylim(0,100)
plt.xlim(-60,80)
    
plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
    
plt.graph()
plt.show()

# %% [markdown]
# # Analysis 1

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#XXX = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
#YYY = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]


plt.scatter(XXX, YYY, marker="o", facecolors="blue", edgecolors="black")


plt.ylim(0,100)
plt.xlim(-60,80)

plt.title("City Latitude vs. Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.graph()
plt.show()

# %% [markdown]
# # Analysis 2

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#XXX = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
#YYY = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

plt.scatter(XXX, YYY, marker="o", facecolors="blue", edgecolors="black")

plt.ylim(0,100)
plt.xlim(-60,80)


plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


plt.graph()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#XXX = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
#YYY = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

plt.scatter(XXX, YYY, marker="o", facecolors="blue", edgecolors="black")

plt.ylim(0, 50)
plt.xlim(-60,80)

plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.graph()
plt.show()

# %% [markdown]
# ## Analysis 3
